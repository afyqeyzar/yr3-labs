# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np

# %%
hdulist= fits.open('./A1_mosaic.fits')
data = hdulist[0].data
header = hdulist[0].header
#plt.imshow(data)
print(header)
# Out:
# SIMPLE  =                    T / Fits standard                                  BITPIX  =                   16 / Bits per pixel                                 NAXIS   =                    2 / Number of axes                                 NAXIS1  =                 2570 / Axis length                                    NAXIS2  =                 4611 / Axis length                                    EXTEND  =                    F / File may contain extensions                    BSCALE  =           1.000000E0 / REAL = TAPE*BSCALE + BZERO                     BZERO   =           3.276800E4 /                                                ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator        DATE    = '2006-03-20T14:56:47' / Date FITS file was generated                  IRAF-TLM= '14:56:45 (20/03/2006)' / Time of last modification                   OBJECT  = 'Lockman_mosaic_r_1046+5902 - DelRA =   0.0, DelDec =   0.0' / Name ofNEXTEND =                    8 / Numbe
# ...

# %%
from unicodedata import normalize


data_small = data[0:500,0:500]
plt.imshow(data_small)

# %%
def find_signal(nested__array):
  background_lower_bound = 3481
  for array in nested__array:
    for pixel_index, pixel_value in enumerate(array):
      if pixel_value > background_lower_bound:
