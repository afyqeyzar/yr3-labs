# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
voltage_violet, current_violet = np.loadtxt('violet_new_setup.csv', delimiter=',',unpack = True, skiprows = 1)

# %%
plt.plot(voltage_violet,current_violet,'x')
plt.grid()
